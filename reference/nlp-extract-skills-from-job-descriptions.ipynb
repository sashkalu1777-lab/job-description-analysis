# %% [markdown]
# # Introduction
#
#
# This project consists of finding a correlation between job descriptions and skills.
#
# We will focus on the following jobs: Data Scientist- Mobile Developer- Account Manager- CTO- CEO

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string
import nltk
from nltk.corpus import stopwords
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from wordcloud import WordCloud

import matplotlib.pyplot as plt
# %matplotlib inline
from textblob import Word
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/job_description_dataset.csv

# %% [markdown]
# # Read data
# The following data was created manually.
#
# I searched for the job titles (CEO, Data scientist etc) needed for this exercise on different websites such as LinkedIn and Indeed. And I parsed the whole job description as it in a csv file.
#
# Let's start by reading this data.

# %%
test = pd.read_csv('/kaggle/input/job_description_dataset.csv')
## Delete empty rows (In case I missed parsing a row)
test = test.dropna()
print("\n ** raw data **\n")
print(test.head())
print("\n ** data shape **\n")
print(test.shape)
# Out:
#  ** raw data **
#
#         job_title                                        description
# 0  Data Scientist  We are looking for Freelance Data Scientists t...
# 1  Data Scientist  It wasn’t so long ago that booking a trip so s...
# 2  Data Scientist  Are you a Data  Scientist or a Data Engineer w...
# 3  Data Scientist  Talos Digital is looking for a Data Scientist ...
# 4  Data Scientist  Job Purpose\n\nAs a Data Scientist in the Roch...
#
#  ** data shape **
#
# (149, 2)

# %% [markdown]
# This data contains 149 job descriptions and is structured into two columns:
#
# * job_title : for the job title.
# * description : raw text describing the job requirements.
#
# Let's now check if our data is balanced and therefore eligible to modeling.

# %%
fig=plt.figure(figsize=(10, 5), dpi= 80, facecolor='w', edgecolor='k')
test.job_title.hist()

# %% [markdown]
# There are approximatively 30 rows for each job.
#
# **Our data is balanced** so let's move on to preprocessing it.

# %% [markdown]
# # Preprocess text data
# Since the data we're now working with is at its rawest form, we need to preprocess it before extracting information from it.
#
# in this step, we will:
# * Convert all text to lower cases
# * Delete all tabulation,spaces, and new lines
# * Delete all numericals
# * Delete nltk's defined stop words
# * Lemmatize text

# %%
## Lower case
test['description'] = test['description'].apply(lambda x: " ".join(x.lower()for x in x.split()))
## remove tabulation and punctuation
test['description'] = test['description'].str.replace('[^\w\s]',' ')
## digits
test['description'] = test['description'].str.replace('\d+', '')

#remove stop words
stop = stopwords.words('english')
test['description'] = test['description'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

## lemmatization
test['description'] = test['description'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

print("Preprocessed data: \n")
print(test.head())
# Out:
# Preprocessed data:
#
#         job_title                                        description
# 0  Data Scientist  looking freelance data scientist join several ...
# 1  Data Scientist  long ago booking trip see eiffel tower stroll ...
# 2  Data Scientist  data scientist data engineer seeking challengi...
# 3  Data Scientist  talos digital looking data scientist help u di...
# 4  Data Scientist  job purpose data scientist roche diabetes care...

# %% [markdown]
# # Visualize data
# In this step, **we will aggregate our data by job titles** in order to visualy detect the most frequent words for each job.

# %%
## jda stands for job description aggregated
jda = test.groupby(['job_title']).sum().reset_index()
print("Aggregated job descriptions: \n")
print(jda)
# Out:
# Aggregated job descriptions:
#
#           job_title                                        description
# 0   Account Manager  responsibility lead communication customer off...
# 1               CEO  role hospital chief executive officer ceo affo...
# 2               CTO  summary description reporting chief executive ...
# 3    Data Scientist  looking freelance data scientist join several ...
# 4  Mobile Developer  zerology looking mobile developer support mobi...

# %%
## Visualize data
jobs_list = jda.job_title.unique().tolist()
for job in jobs_list:

    # Start with one review:
    text = jda[jda.job_title == job].iloc[0].description
    # Create and generate a word cloud image:
    wordcloud = WordCloud().generate(text)
    print("\n***",job,"***\n")
    # Display the generated image:
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
# Out:
# *** Account Manager ***
# *** CEO ***
# *** CTO ***
# *** Data Scientist ***
# *** Mobile Developer ***

# %% [markdown]
# I noticed the presence of meaningless words such as: Technology, Organization, Company.
# As well as the presence of the job title itself.
#
# We can safely delete these words from our data.

# %%
## Delete more stop words
other_stop_words = ['junior', 'senior','experience','etc','job','work','company','technique',
                    'candidate','skill','skills','language','menu','inc','new','plus','years',
                   'technology','organization','ceo','cto','account','manager','data','scientist','mobile',
                    'developer','product','revenue','strong']

test['description'] = test['description'].apply(lambda x: " ".join(x for x in x.split() if x not in other_stop_words))

# %% [markdown]
# # Modeling
# We are now going to translate this skill-extraction problem into a classification one first.
# And then extract the most important features from each class.
#
# The most important features, in this case, represent the words that most likely will belong to a class ( in our case job title)

# %% [markdown]
# I chose for this exercise to train the naive bayes algorithm.

# %%
## Converting text to features 
vectorizer = TfidfVectorizer()
#Tokenize and build vocabulary
X = vectorizer.fit_transform(test.description)
y = test.job_title

# split data into 80% training and 20% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=109) 
print("train data shape: ",X_train.shape)
print("test data shape: ",X_test.shape)

# Fit model
clf = MultinomialNB()
clf.fit(X_train, y_train)
## Predict
y_predicted = clf.predict(X_test)
# Out:
# train data shape:  (119, 4547)
# test data shape:  (30, 4547)

# %% [markdown]
# Let's do a quick sanity check for the distribution of our train and test data.

# %%
y_train.hist()
y_test.hist()

# %% [markdown]
# ## MODEL EVALUATION

# %%
#evaluate the predictions
print("Accuracy score is: ",accuracy_score(y_test, y_predicted))
print("Classes: (to help read Confusion Matrix)\n", clf.classes_)
print("Confusion Matrix: ")

print(confusion_matrix(y_test, y_predicted))
print("Classification Report: ")
print(classification_report(y_test, y_predicted))
# Out:
# Accuracy score is:  0.8
# Classes: (to help read Confusion Matrix)
#  ['Account Manager' 'CEO' 'CTO' 'Data Scientist' 'Mobile Developer']
# Confusion Matrix:
# [[5 0 0 0 0]
#  [0 5 3 0 0]
#  [0 0 2 1 1]
#  [0 0 0 6 1]
#  [0 0 0 0 6]]
# Classification Report:
#                   precision    recall  f1-score   support
#
#  Account Manager       1.00      1.00      1.00         5
#              CEO       1.00      0.62      0.77         8
#              CTO       0.40      0.50      0.44         4
#   Data Scientist       0.86      0.86      0.86         7
# Mobile Developer       0.75      1.00      0.86         6
#
#         accuracy                           0.80        30
#        macro avg       0.80      0.80      0.79        30
#     weighted avg       0.84      0.80      0.80        30

# %% [markdown]
# # Model evaluation and interpretation
# **Our accuracy score is 80% which is acceptable.**
#
# *NOTE:* Model accuracy dropped down after deleting the job titles from their respective descriptions. Which is expectable. ( If most job descriptions for CEO contain the word CEO, then the token CEO will be the most important feature for the class CEO)
#
# This way our model will give more weight to other remaining/meaningful tokens

# %% [markdown]
# The confusion matrix shows that the features for the account manager, data scientist and mobile developer are differenciable. Therefore, we expect to extract meaningful features out of these classes.
#
# Meanwhile, 3 out of 8 CEO classes were classified as CTO. So there is a little confusion between CTO and CEO.
# And 2 out of 4 CTO classes were classified as Data Scientist and Mobile developer. I think this is due to the fact that in training data there was less CTO data than the rest.

# %% [markdown]
# # Feature extraction
# Let's now extract the most meaningful features of each class.
#
# To do so, we can access the attribute *feature_log_prob_* from our model which returns the log probability of features given a class.
#
# We will next sort the log probabilies descendingly.
#
# And finally map the most important tokens to the classes

# %%
print(clf.coef_)
print(clf.coef_.shape)
# Out:
# [[-8.43062501 -7.80019193 -8.28422135 ... -8.4772855  -8.4772855
#   -8.4772855 ]
#  [-8.47205413 -7.98334489 -8.40416058 ... -8.40912003 -8.44009208
#   -8.44009208]
#  [-8.47827676 -7.75321972 -8.14619705 ... -8.47827676 -8.47827676
#   -8.47827676]
#  [-8.4724407  -8.00421077 -8.24392093 ... -8.4724407  -8.4724407
#   -8.4724407 ]
#  [-8.47631345 -8.26123509 -8.1429054  ... -8.47631345 -8.47631345
#   -8.47631345]]
# (5, 4547)

# %% [markdown]
# # Output
# At this step, we have for each class/job a list of the most representative words/tokens found in job descriptions.
#
# Let's shrink this list of words to only:
# * 6 technical skills
# * 6 adjectives
#
# To do so, we use the library *TextBlob* to identify adjectives.
#
# Also, given a (non-exhaustive) list of programming languages, we can extract the top technical skills.

# %%
from textblob import TextBlob
technical_skills = ['python', 'c','r', 'c++','java','hadoop','scala','flask','pandas','spark','scikit-learn',
                    'numpy','php','sql','mysql','css','mongdb','nltk','fastai' , 'keras', 'pytorch','tensorflow',
                   'linux','Ruby','JavaScript','django','react','reactjs','ai','ui','tableau']
feature_array = vectorizer.get_feature_names()
# number of overall model features
features_numbers = len(feature_array)
## max sorted features number
n_max = int(features_numbers * 0.1)

##initialize output dataframe
output = pd.DataFrame()
for i in range(0,len(clf.classes_)):
    print("\n****" ,clf.classes_[i],"****\n")
    class_prob_indices_sorted = clf.feature_log_prob_[i, :].argsort()[::-1]
    raw_skills = np.take(feature_array, class_prob_indices_sorted[:n_max])
    print("list of unprocessed skills :")
    print(raw_skills)
    
    ## Extract technical skills
    top_technical_skills= list(set(technical_skills).intersection(raw_skills))[:6]
    #print("Top technical skills",top_technical_skills)
    
    ## Extract adjectives
    
    # Delete technical skills from raw skills list
    ## At this steps, raw skills list doesnt contain the technical skills
    #raw_skills = [x for x in raw_skills if x not in top_technical_skills]
    #raw_skills = list(set(raw_skills) - set(top_technical_skills))

    # transform list to string
    txt = " ".join(raw_skills)
    blob = TextBlob(txt)
    #top 6 adjective
    top_adjectives = [w for (w, pos) in TextBlob(txt).pos_tags if pos.startswith("JJ")][:6]
    #print("Top 6 adjectives: ",top_adjectives)
    
    output = output.append({'job_title':clf.classes_[i],
                        'technical_skills':top_technical_skills,
                        'soft_skills':top_adjectives },
                       ignore_index=True)
# Out:
# **** Account Manager ****
#
# list of unprocessed skills :
# ['client' 'sale' 'customer' 'business' 'relationship' 'solution' 'team'
#  'management' 'service' 'need' 'ability' 'ensure' 'opportunity'
#  'territory' 'marketing' 'provide' 'manage' 'satisfaction' 'campaign'
#  'assigned' 'existing' 'develop' 'responsible' 'technical' 'siren'
#  'including' 'support' 'drive' 'industry' 'key' 'grow' 'kaseya' 'project'
#  'within' 'fis' 'production' 'communication' 'altair' 'environment' 'year'
#  'goal' 'semiconductor' 'selling' 'partner' 'google' 'well' 'presentation'
#  'successful' 'working' 'portfolio' 'strategic' 'growth' 'timely'
#  'manages' 'identify' 'area' 'ad' 'professional' 'high' 'platform' 'plan'
#  'role' 'activity' 'strategy' 'delivery' 'meet' 'level' 'lead' 'meeting'
#  'safety' 'advertising' 'arcesium' 'preferred' 'maintain' 'internal'
#  'contact' 'target' 'excel' 'proactively' 'knowledge' 'build' 'employee'
#  'excellent' 'understanding' 'degree' 'fast' 'responsibility' 'success'
#  'complex' 'department' 'establish' 'travel' 'required' 'financial'
#  'industrial' 'identifying' 'expectation' 'base' 'competitive' 'time'
#  'retention' 'onboarding' 'ensuring' 'potential' 'self' 'position'
#  'established' 'market' 'crm' 'enhancement' 'office' 'prospect' 'health'
#  'track' 'effectively' 'effective' 'development' 'infor' 'profitability'
#  'record' 'system' 'maintaining' 'best' 'people' 'decision' 'relevant'
#  'communicate' 'issue' 'bachelor' 'bay' 'pcnation' 'member' 'range'
#  'paced' 'powder' 'coating' 'sound' 'budget' 'engineering' 'help' 'report'
#  'understand' 'helping' 'tiktok' 'ideal' 'policy' 'articulate' 'provider'
#  'item' 'contract' 'daily' 'close' 'quality' 'requirement' 'monthly'
#  'written' 'motivated' 'achieve' 'electronics' 'condition' 'complete'
#  'care' 'vendor' 'positive' 'volume' 'schedule' 'value' 'regular'
#  'process' 'offer' 'address' 'growing' 'creative' 'microsoft' 'individual'
#  'space' 'priority' 'driven' 'create' 'supporting' 'challenge'
#  'consultative' 'manner' 'managing' 'program' 'proposal' 'advertiser'
#  'achievement' 'multiple' 'training' 'detail' 'conduct' 'chain' 'part'
#  'set' 'passion' 'list' 'altran' 'attention' 'oral' 'reporting'
#  'background' 'building' 'word' 'external' 'providing' 'large' 'looking'
#  'negotiating' 'request' 'appropriate' 'staff' 'life' 'pro' 'needed'
#  'owns' 'must' 'point' 'benefit' 'quarterly' 'quota' 'call' 'boston'
#  'problem' 'supply' 'essential' 'forecast' 'exceptional' 'qualification'
#  'summary' 'escalation' 'follow' 'willing' 'improve' 'expert' 'win'
#  'action' 'metric' 'objective' 'acumen' 'collaborate' 'review'
#  'partnership' 'driving' 'cross' 'negotiate' 'delivering' 'roche'
#  'referral' 'interpersonal' 'active' 'named' 'currently' 'monitoring'
#  'long' 'commission' 'across' 'task' 'related' 'expand' 'user'
#  'communicates' 'trend' 'leadership' 'deviation' 'may' 'line' 'commercial'
#  'solve' 'quickly' 'first' 'resourcing' 'onboard' 'ppl' 'judgment'
#  'primary' 'nurture' 'result' 'class' 'processing' 'stakeholder' 'patient'
#  'repeat' 'performance' 'vision' 'outside' 'analytics' 'like' 'throughout'
#  'others' 'global' 'retail' 'risk' 'post' 'energetic' 'dynamic' 'ip'
#  'upper' 'grad' 'scm' 'sell' 'starter' 'execute' 'basic' 'video' 'duty'
#  'analyzing' 'via' 'term' 'completion' 'social' 'lab' 'cycle' 'outbound'
#  'overall' 'uncapped' 'digital' 'proven' 'software' 'negotiation' 'able'
#  'partnered' 'corporate' 'highly' 'use' 'day' 'procedure' 'efficiently'
#  'liaise' 'medical' 'posse' 'become' 'constructive' 'optimization'
#  'education' 'present' 'comprehensive' 'regarding' 'san' 'situation'
#  'take' 'weekly' 'join' 'field' 'great' 'expansion' 'clear' 'encouraged'
#  'powerpoint' 'description' 'ownership' 'closely' 'always' 'one' 'enjoys'
#  'train' 'maker' 'nw' 'indiana' 'ohio' 'akzonobel' 'bug' 'po' 'local'
#  'broadly' 'educate' 'question' 'deep' 'challenging' 'provides' 'sock'
#  'consistent' 'met' 'resolve' 'transition' 'based' 'simultaneously'
#  'conversation' 'prioritize' 'inventory' 'clinical' 'monitor'
#  'demonstrates' 'adding' 'open' 'entertainment' 'agency' 'specific'
#  'making' 'proper' 'standard' 'prospective' 'coordinate' 'month'
#  'diabetes' 'identifies' 'purpose' 'deliverable' 'group' 'downtown'
#  'tactical' 'giving' 'satisfied' 'serve' 'qualify' 'prepare' 'deadline'
#  'participate' 'componants' 'vivid' 'prior' 'right' 'focused' 'recent'
#  'achieving' 'successfully' 'online' 'autonomy' 'past' 'consulting'
#  'design' 'equivalent' 'adoption' 'custom' 'enterprise' 'developed'
#  'anticipate' 'necessary' 'share' 'outlook' 'concern' 'student'
#  'manufacturing' 'supervisor' 'minimal' 'learn' 'northern' 'executive'
#  'unsafe' 'make' 'medium' 'deliver' 'proactive' 'change' 'organizational'
#  'order' 'demonstrated' 'visit' 'developing' 'internet' 'cambridge'
#  'antibody' 'thrives' 'insight']
#
# **** CEO ****
#
# list of unprocessed skills :
# ['board' 'care' 'health' 'leadership' 'strategic' 'management' 'executive'
#  'operation' 'housing' 'business' 'financial' 'mental' 'community'
#  'program' 'employee' 'hospital' 'development' 'team' 'service'
#  'performance' 'director' 'year' 'growth' 'association' 'including'
#  'arbor' 'high' 'acute' 'position' 'ability' 'patient' 'industry'
#  'robotics' 'degree' 'responsibility' 'quality' 'result' 'member' 'plan'
#  'goal' 'provide' 'president' 'chief' 'public' 'strategy' 'overall'
#  'culture' 'build' 'agency' 'preferred' 'lead' 'proven' 'officer'
#  'develop' 'state' 'better' 'homelessness' 'staff' 'future' 'marketing'
#  'operational' 'dedication' 'regulatory' 'ensure' 'opportunity' 'value'
#  'mission' 'past' 'provides' 'planning' 'research' 'fundraising'
#  'education' 'policy' 'healthcare' 'oklahoma' 'seeking' 'budget' 'term'
#  'five' 'ml' 'role' 'leader' 'nevada' 'oriented' 'uhs' 'general' 'support'
#  'page' 'solomon' 'setting' 'mm' 'required' 'earlydx' 'level'
#  'environment' 'mba' 'key' 'profit' 'vision' 'excellent' 'effort' 'union'
#  'success' 'understanding' 'long' 'objective' 'responsible' 'promote'
#  'information' 'also' 'corporation' 'delaware' 'non' 'tulsa' 'socu'
#  'specialty' 'canvas' 'continued' 'partnership' 'qualification'
#  'behavioral' 'consulting' 'developing' 'stage' 'top' 'finance' 'leading'
#  'oversee' 'marketplace' 'employment' 'credit' 'family' 'highly' 'expand'
#  'reporting' 'working' 'establishing' 'raising' 'implement' 'recognized'
#  'mhaok' 'ideal' 'establish' 'superior' 'meeting' 'early' 'fiscal'
#  'nonprofit' 'acquisition' 'process' 'eye' 'providing' 'experienced'
#  'annual' 'overseeing' 'requirement' 'project' 'relation' 'positive'
#  'institution' 'area' 'communication' 'personnel' 'related' 'function'
#  'organizational' 'needed' 'drive' 'effective' 'history' 'people' 'social'
#  'initiative' 'advanced' 'accountability' 'nationally' 'offer' 'bachelor'
#  'individual' 'sale' 'partner' 'funding' 'search' 'direct' 'estate'
#  'exceptional' 'budgeting' 'growing' 'career' 'northern' 'software'
#  'physician' 'regional' 'relationship' 'clinical' 'consumer' 'seek'
#  'accredited' 'must' 'capital' 'reno' 'record' 'achieve' 'committee'
#  'administration' 'bringing' 'duty' 'haiti' 'fragile' 'increase'
#  'maintenance' 'country' 'treatment' 'knowledge' 'manufacturing' 'size'
#  'metric' 'resource' 'property' 'medical' 'consensus' 'report' 'manage'
#  'attracting' 'negotiation' 'ever' 'employer' 'join' 'private' 'market'
#  'extensive' 'include' 'outreach' 'wolfe' 'clinic' 'demonstrated' 'need'
#  'decision' 'national' 'next' 'ywca' 'childhood' 'track' 'cfo'
#  'continuing' 'focus' 'performing' 'day' 'local' 'brand' 'represent'
#  'regulated' 'raise' 'interested' 'event' 'hand' 'effectiveness'
#  'accountable' 'ebitda' 'engineering' 'devoted' 'centered' 'hardworking'
#  'mha' 'authentic' 'excellence' 'guide' 'access' 'appropriate' 'maintain'
#  'current' 'united' 'within' 'procedure' 'child' 'managing' 'startup' 'il'
#  'specific' 'building' 'least' 'rule' 'would' 'medium' 'hiring' 'moving'
#  'closely' 'based' 'performer' 'extraordinary' 'per' 'solid' 'successful'
#  'law' 'guidance' 'effectively' 'benefit' 'minnesota' 'unique' 'today'
#  'real' 'application' 'practice' 'wide' 'affordable' 'customer'
#  'retaining' 'notch' 'volunteer' 'genesis' 'environmental' 'universal'
#  'similar' 'profitability' 'liquid' 'biopsy' 'technical' 'multiple' 'west'
#  'direction' 'negotiating' 'addition' 'desired' 'fund' 'party' 'grant'
#  'shareholder' 'across' 'increasing' 'set' 'focusing' 'genomics'
#  'undiagnosed' 'interpersonal' 'achieved' 'equivalent' 'accurate'
#  'additional' 'select' 'subsidiary' 'alliance' 'fast' 'applicant' 'serial'
#  'owner' 'engaging' 'serve' 'academic' 'embedded' 'diverse' 'corporate'
#  'training' 'enhance' 'continuously' 'disability' 'additionally' 'firm'
#  'core' 'relocation' 'experiencing' 'justice' 'delivering' 'refine'
#  'field' 'major' 'challenge' 'owned' 'make' 'facility' 'workplace' 'line'
#  'potential' 'precision' 'commercialization' 'pathway' 'positioning'
#  'throughout' 'connect' 'critical' 'improvement' 'asset' 'currently'
#  'changing' 'good' 'alumnus' 'ldi' 'cancer' 'together' 'supervises'
#  'complex' 'human' 'others' 'safety' 'advocacy' 'criminal' 'operating'
#  'review' 'thinker' 'indicator' 'identifies' 'previous' 'distribution'
#  'seed' 'biotech' 'enterprise' 'life' 'acumen' 'resume' 'delivers' 'trust'
#  'large' 'shared' 'production' 'improve' 'federal' 'compensation'
#  'proposal' 'progressive' 'participates' 'hill' 'analysis' 'expansion'
#  'investor' 'verbal' 'accreditation' 'deal' 'medicine' 'government'
#  'participant' 'municipal' 'wastewater' 'canton' 'shelter' 'woman'
#  'activity' 'spokesperson' 'entire' 'contractor' 'undergraduate'
#  'personal' 'unit' 'implementation' 'cutting' 'serf' 'entrepreneurial'
#  'minimum' 'led' 'travel' 'edge' 'full' 'deliver' 'one' 'serving']
#
# **** CTO ****
#
# list of unprocessed skills :
# ['team' 'technical' 'twilio' 'business' 'engineering' 'technological'
#  'chief' 'officer' 'ability' 'leadership' 'strategy' 'development'
#  'system' 'infrastructure' 'strategic' 'ensure' 'software' 'recruitment'
#  'management' 'customer' 'level' 'role' 'leader' 'process' 'looking'
#  'excellent' 'manage' 'leading' 'well' 'information' 'growth' 'budget'
#  'trend' 'practice' 'vision' 'microsoft' 'platform' 'implement'
#  'executive' 'goal' 'responsibility' 'problem' 'design' 'aspect'
#  'department' 'security' 'current' 'must' 'implementation' 'key' 'lead'
#  'use' 'partner' 'across' 'operation' 'decision' 'user' 'support'
#  'responsible' 'center' 'plan' 'future' 'communication' 'year'
#  'enterprise' 'build' 'managing' 'based' 'stakeholder' 'efficiency'
#  'global' 'environment' 'used' 'direction' 'member' 'go' 'organizational'
#  'solution' 'science' 'position' 'health' 'service' 'knowledge' 'phage'
#  'high' 'drive' 'quality' 'performance' 'operating' 'hand' 'area'
#  'standard' 'make' 'develop' 'requirement' 'growing' 'proven' 'related'
#  'one' 'time' 'way' 'success' 'client' 'tool' 'think' 'feedback'
#  'significant' 'delivery' 'building' 'relevant' 'someone' 'globally'
#  'focus' 'required' 'selected' 'change' 'solving' 'get' 'computer'
#  'oversee' 'great' 'best' 'roadmap' 'take' 'highly' 'anyone' 'hire'
#  'champ' 'reigning' 'maintain' 'azure' 'mentoring' 'capability' 'part'
#  'vendor' 'collaborative' 'availability' 'also' 'able' 'staff' 'metric'
#  'comfortable' 'top' 'improvement' 'cost' 'architecture' 'saas' 'may'
#  'making' 'degree' 'successful' 'ensuring' 'canvas' 'patient'
#  'application' 'versed' 'planning' 'create' 'protection' 'bonus' 'working'
#  'industry' 'play' 'corporation' 'latest' 'group' 'scale' 'effective'
#  'help' 'bring' 'professional' 'kpis' 'closely' 'people' 'internal'
#  'collaborate' 'approach' 'frank' 'saab' 'need' 'competitive' 'huge'
#  'physical' 'exceptional' 'person' 'developing' 'complex' 'multiple'
#  'field' 'communicate' 'objective' 'risk' 'monitor' 'define' 'defining'
#  'extremely' 'external' 'manufacturing' 'right' 'alignment' 'startup'
#  'opportunity' 'include' 'project' 'architectural' 'fast' 'culture'
#  'relationship' 'outstanding' 'compliance' 'track' 'function' 'facing'
#  'remote' 'needed' 'review' 'travel' 'ten' 'necessary' 'ba' 'director'
#  'salary' 'florida' 'benefit' 'identify' 'employee' 'efficient' 'provide'
#  'roadmaps' 'christy' 'assurance' 'tech' 'yield' 'bsc' 'marketing'
#  'audience' 'procedure' 'overall' 'adjustment' 'existing' 'preferred'
#  'market' 'life' 'operational' 'small' 'select' 'dedicated' 'graduate'
#  'network' 'commerce' 'mba' 'want' 'clear' 'execution' 'exciting' 'pcb'
#  'control' 'ass' 'fill' 'electric' 'utility' 'capitalized' 'utlimately'
#  'consumer' 'architecting' 'interpersonal' 'accountability' 'resource'
#  'demonstrated' 'web' 'advantage' 'engagement' 'record' 'personality'
#  'bringing' 'innovative' 'location' 'investor' 'believe' 'place' 'built'
#  'thinking' 'functionality' 'helping' 'discus' 'learning' 'within' 'paced'
#  'direct' 'functionally' 'continuously' 'including' 'energy' 'better'
#  'self' 'south' 'loss' 'experienced' 'proactive' 'worldwide' 'distributed'
#  'perform' 'essential' 'idea' 'maintenance' 'similar' 'enable' 'creative'
#  'acenda' 'profitably' 'demand' 'research' 'managed' 'wide' 'coach'
#  'evaluation' 'ca' 'coaching' 'write' 'financial' 'supporting' 'thinker'
#  'guidance' 'pto' 'activity' 'setting' 'performing' 'functional' 'duty'
#  'researching' 'outside' 'implementing' 'progressively' 'owner' 'deep'
#  'history' 'program' 'cloud' 'incredible' 'launch' 'familiar' 'content'
#  'talent' 'partnering' 'facility' 'hard' 'office' 'posse' 'communicator'
#  'regulatory' 'education' 'important' 'integral' 'aptitude' 'establish'
#  'san' 'tuned' 'innovation' 'ambitious' 'stack' 'transforming'
#  'completion' 'inspire' 'particular' 'expect' 'appropriately' 'evolving'
#  'entrepreneurial' 'action' 'equity' 'expertise' 'video' 'positive'
#  'healthcare' 'apply' 'understanding' 'healthywage' 'weight' 'world'
#  'capital' 'initiative' 'expanding' 'long' 'speak' 'intelligence'
#  'technically' 'analytical' 'thrive' 'cross' 'term' 'engineer'
#  'prioritize' 'artificial' 'objectively' 'compute' 'resiliency'
#  'fostering' 'critically' 'applicability' 'pipeline' 'firm' 'sound'
#  'enabled' 'detail' 'creating' 'issue' 'oriented' 'acquisition' 'attract'
#  'paid' 'class' 'corporate' 'machine' 'train' 'sprint' 'model' 'improve'
#  'sap' 'qualification' 'career' 'least' 'flexible' 'analysis' 'understand'
#  'last' 'devops' 'cso' 'mission' 'persistent' 'foundational' 'distill'
#  'concrete' 'ambiguity' 'evangelizing' 'representing' 'implication'
#  'quick' 'focusing' 'common' 'translate' 'everyone' 'state' 'interested'
#  'big' 'influence' 'site' 'abreast' 'effectively' 'properly' 'please'
#  'agenda' 'find' 'extensive' 'secure']
#
# **** Data Scientist ****
#
# list of unprocessed skills :
# ['science' 'learning' 'model' 'machine' 'algorithm' 'statistic'
#  'analytics' 'python' 'business' 'predictive' 'working' 'analysis'
#  'knowledge' 'statistical' 'tool' 'team' 'insight' 'computer' 'ai'
#  'client' 'project' 'customer' 'modelling' 'problem' 'mining'
#  'mathematics' 'pricing' 'processing' 'research' 'modeling' 'quantitative'
#  'master' 'looking' 'method' 'using' 'development' 'field' 'decision'
#  'degree' 'natural' 'develop' 'opportunity' 'analytical' 'english' 'good'
#  'ability' 'year' 'technical' 'source' 'solution' 'highly' 'phd'
#  'programming' 'real' 'set' 'stakeholder' 'following' 'savana' 'deep'
#  'analytic' 'role' 'least' 'well' 'library' 'unique' 'clustering'
#  'understand' 'within' 'clinical' 'neural' 'related' 'medical' 'large'
#  'global' 'support' 'cloud' 'build' 'commerce' 'dso' 'world' 'detection'
#  'based' 'framework' 'engineering' 'requirement' 'optimization'
#  'classification' 'sql' 'maintenance' 'similar' 'variety' 'result'
#  'relevant' 'ml' 'environment' 'software' 'way' 'like' 'driven' 'database'
#  'time' 'network' 'several' 'big' 'approach' 'professional' 'datasets'
#  'join' 'including' 'automotive' 'marketing' 'creating' 'challenging'
#  'management' 'practice' 'scala' 'operation' 'apply' 'across' 'please'
#  'building' 'optimisation' 'function' 'recommendation' 'wide'
#  'qualification' 'expertise' 'hand' 'need' 'passionate' 'communication'
#  'regression' 'platform' 'applying' 'level' 'flexible' 'latest' 'cutting'
#  'innovative' 'complex' 'mine' 'behaviour' 'diabetes' 'accuracy' 'impact'
#  'minimum' 'computing' 'edge' 'deliver' 'pytorch' 'currently' 'required'
#  'developing' 'fraud' 'msc' 'industry' 'hadoop' 'question' 'range' 'hive'
#  'market' 'different' 'preferably' 'numpy' 'reinforcement' 'nlp'
#  'excellent' 'aws' 'analyze' 'engineer' 'free' 'solving' 'vehicle' 'price'
#  'key' 'spark' 'understanding' 'discipline' 'non' 'digital' 'fleet' 'also'
#  'implement' 'fluent' 'architecture' 'communicate' 'outcome' 'drive'
#  'information' 'ad' 'performance' 'responsibility' 'specific' 'part'
#  'help' 'office' 'delivering' 'background' 'evaluate' 'scripting'
#  'million' 'process' 'economics' 'creative' 'algorithmic' 'healthcare'
#  'developed' 'advise' 'career' 'europe' 'monitoring' 'freelance'
#  'worksuite' 'tensorflow' 'one' 'actionable' 'tree' 'tackle' 'start'
#  'able' 'unstructured' 'leverage' 'chatbots' 'feel' 'design'
#  'intelligence' 'learn' 'mix' 'position' 'spoken' 'eg' 'artificial'
#  'retail' 'make' 'amount' 'gathering' 'interest' 'familiarity' 'house'
#  'written' 'take' 'end' 'answer' 'collaboration' 'transforming'
#  'mapreduce' 'open' 'context' 'difficult' 'solid' 'look' 'anomaly'
#  'expert' 'post' 'nosql' 'risk' 'deployment' 'system' 'doctorate'
#  'soemone' 'intersting' 'profficient' 'piplines' 'challenge' 'must' 'ey'
#  'identify' 'insurance' 'evidence' 'dynamic' 'segmentation' 'interpreting'
#  'common' 'international' 'advanced' 'application' 'exposure' 'deadline'
#  'prediction' 'sector' 'day' 'hoc' 'visualization' 'present' 'include'
#  'future' 'entrepreneurial' 'various' 'ass' 'netherlands' 'lake'
#  'assessing' 'existing' 'seeking' 'benefit' 'responsible' 'group' 'shape'
#  'region' 'matlab' 'order' 'record' 'mathematical' 'kera' 'scikit'
#  'bachelor' 'electronic' 'kellogg' 'basic' 'shiny' 'finish' 'modern'
#  'issue' 'finding' 'leveraging' 'strategy' 'area' 'scalable' 'equivalent'
#  'best' 'testing' 'grds' 'applied' 'university' 'msci' 'panda' 'use'
#  'around' 'multiple' 'driving' 'transformation' 'people' 'functional'
#  'preferred' 'capability' 'considered' 'desire' 'german' 'sa' 'accelerate'
#  'inform' 'average' 'someone' 'google' 'draw' 'london' 'asset'
#  'commercial' 'targeting' 'collaborative' 'physic' 'valuable' 'thinking'
#  'profile' 'agile' 'passion' 'improving' 'acumen' 'experienced' 'image'
#  'point' 'stay' 'rapidly' 'utilise' 'value' 'paypal' 'paradigm' 'wider'
#  'offer' 'custom' 'personalised' 'peer' 'tableau' 'limited' 'making'
#  'researching' 'structure' 'ideally' 'translate' 'descriptive' 'emphasis'
#  'managing' 'text' 'exciting' 'methodology' 'consultant' 'monitor'
#  'effectiveness' 'bi' 'graduate' 'scipy' 'scapy' 'milan' 'plotly' 'dash'
#  'toolkit' 'deeplearning' 'representation' 'internal' 'choice' 'emerging'
#  'interacting' 'putting' 'behavior' 'advantage' 'grow' 'forefront'
#  'production' 'principle' 'patient' 'ethical' 'methodical' 'population'
#  'solve' 'enable' 'optimize' 'local' 'sense' 'vision' 'may' 'reusable'
#  'curiosity' 'ownership' 'julia' 'improve' 'expects' 'fintech' 'mark'
#  'reporting' 'experimentation' 'hp' 'multivariate' 'parametric' 'py'
#  'vizualization' 'charm' 'manipulate' 'stochastic' 'flink' 'intermediate'
#  'player' 'standard' 'colleague' 'academic' 'spirit' 'meaningful'
#  'defining' 'chance' 'driver' 'enrich' 'carrying' 'mckinsey' 'send'
#  'great']
#
# **** Mobile Developer ****
#
# list of unprocessed skills :
# ['development' 'application' 'io' 'android' 'software' 'design' 'code'
#  'team' 'platform' 'native' 'project' 'react' 'app' 'knowledge' 'web'
#  'end' 'working' 'developing' 'test' 'service' 'apps' 'year'
#  'understanding' 'quality' 'agile' 'javascript' 'swift' 'node' 'world'
#  'solution' 'testing' 'using' 'technical' 'xamarin' 'system' 'requirement'
#  'integration' 'client' 'one' 'net' 'environment' 'looking' 'best'
#  'develop' 'first' 'engineer' 'people' 'architecture' 'kotlin' 'good'
#  'customer' 'studio' 'business' 'apis' 'rest' 'crypto' 'java' 'build'
#  'join' 'engineering' 'user' 'help' 'git' 'high' 'digital' 'pattern'
#  'component' 'paypal' 'market' 'advanced' 'participate' 'support' 'layout'
#  'hybrid' 'proficiency' 'based' 'issue' 'standard' 'scrum' 'practice'
#  'architect' 'deliver' 'start' 'together' 'zemoga' 'passion' 'capgemini'
#  'responsibility' 'passionate' 'create' 'core' 'control' 'amazing'
#  'improve' 'offer' 'problem' 'cutting' 'html' 'api' 'able' 'growin' 'role'
#  'driven' 'part' 'ui' 'com' 'angular' 'writing' 'framework' 'minimum'
#  'startup' 'feature' 'field' 'security' 'xcode' 'guideline' 'sql' 'unit'
#  'play' 'document' 'methodology' 'cd' 'ci' 'make' 'backend' 'typescript'
#  'around' 'profile' 'full' 'lifecycle' 'industry' 'kin' 'banking' 'edge'
#  'required' 'growing' 'also' 'release' 'brand' 'side' 'berlin'
#  'restaurant' 'resq' 'programming' 'ionic' 'principle' 'learning' 'asp'
#  'line' 'active' 'innovation' 'description' 'solving' 'coding' 'store'
#  'career' 'complex' 'healthcare' 'resolve' 'like' 'lead' 'specifically'
#  'efficient' 'maintain' 'personal' 'benefit' 'expertise' 'self' 'clean'
#  'better' 'appium' 'opportunity' 'server' 'cloud' 'attitude' 'class'
#  'experienced' 'member' 'lunch' 'documentation' 'grow' 'stack'
#  'communication' 'well' 'group' 'attractive' 'apple' 'freedom'
#  'assurecare' 'believe' 'tool' 'amazon' 'according' 'million' 'following'
#  'familiarity' 'day' 'level' 'global' 'daily' 'place' 'deep' 'management'
#  'money' 'object' 'deployment' 'objective' 'preferred' 'concept' 'cordova'
#  'designing' 'ux' 'ups' 'dynamic' 'json' 'nodejs' 'designer' 'interface'
#  'solve' 'computer' 'ticket' 'onespan' 'automation' 'cs' 'open' 'auto'
#  'matter' 'perform' 'designed' 'groovy' 'free' 'stay' 'highly' 'degree'
#  'mentor' 'cross' 'google' 'alongside' 'write' 'microservices' 'jump'
#  'ability' 'enables' 'provide' 'closely' 'still' 'english' 'technological'
#  'expert' 'owner' 'keep' 'international' 'desired' 'lot' 'myriad'
#  'specific' 'time' 'facilitate' 'equivalent' 'name' 'bitbucket' 'exciting'
#  'leader' 'related' 'approach' 'change' 'established' 'oporto'
#  'asynchronous' 'threaded' 'winprovit' 'top' 'troubleshooting' 'financial'
#  'department' 'performance' 'analyst' 'talented' 'apache' 'currency'
#  'process' 'cyber' 'colombia' 'detailed' 'version' 'demonstrated'
#  'creativity' 'debug' 'delivery' 'excellent' 'entire' 'would' 'across'
#  'building' 'motivating' 'remuneration' 'fortune' 'allowance' 'serve'
#  'encourage' 'know' 'linux' 'way' 'speed' 'form' 'scripting' 'review'
#  'multi' 'attend' 'deploying' 'enterprise' 'style' 'different'
#  'interested' 'resolution' 'solid' 'huge' 'simple' 'receive' 'several'
#  'compliance' 'technologically' 'depth' 'life' 'domain' 'fully' 'suggest'
#  'emerging' 'powerful' 'hard' 'ensure' 'renowned' 'leading' 'supporting'
#  'fundamental' 'current' 'azure' 'sharing' 'window' 'white' 'sdk'
#  'labeled' 'transportation' 'focus' 'colleague' 'trend' 'debugging'
#  'payment' 'suite' 'improvement' 'qa' 'desire' 'learner' 'front' 'meet'
#  'gitbash' 'winscp' 'jmeter' 'soapui' 'oriented' 'information' 'python'
#  'basis' 'key' 'within' 'individual' 'gather' 'recruiting' 'ownership'
#  'every' 'office' 'mission' 'infrastructure' 'thought' 'strategy'
#  'reading' 'billbuddy' 'proven' 'program' 'moderately' 'mvc' 'staying'
#  'challenging' 'step' 'salary' 'need' 'back' 'collaborative'
#  'participation' 'cryptocurrency' 'dog' 'right' 'space' 'culture'
#  'germany' 'performant' 'friday' 'globe' 'autonomous' 'upto' 'outcome'
#  'source' 'future' 'visio' 'built' 'come' 'planning' 'escalate' 'incident'
#  'structure' 'procedure' 'analytical' 'care' 'written' 'provisioning'
#  'relevant' 'gradle' 'including' 'assist' 'mentorship' 'carta' 'towards'
#  'device' 'uk' 'achieve' 'balance' 'considerable' 'assurance' 'budget'
#  'preferably' 'must' 'fastest' 'atlassian' 'promise' 'massively' 'harvey'
#  'nash' 'browserstack' 'ireland' 'get' 'equal' 'provider' 'coming'
#  'translate' 'science' 'certification' 'nice' 'mac' 'catered' 'reality'
#  'everyone' 'documenting' 'mind' 'mandatory']

# %% [markdown]
# Correlation between jobs and skills:

# %%
print(output.T)
# Out:
#                                                                   0  \
# job_title                                           Account Manager
# soft_skills       [responsible, technical, key, grow, fis, succe...
# technical_skills                                                 []
#
#                                                                   1  \
# job_title                                                       CEO
# soft_skills       [strategic, financial, mental, arbor, high, ch...
# technical_skills                                                 []
#
#                                                                   2  \
# job_title                                                       CTO
# soft_skills       [technical, technological, chief, strategic, r...
# technical_skills                                                 []
#
#                                                                   3  \
# job_title                                            Data Scientist
# soft_skills       [statistic, predictive, statistical, quantitat...
# technical_skills      [ai, hadoop, spark, python, tableau, pytorch]
#
#                                                                4
# job_title                                       Mobile Developer
# soft_skills       [native, react, app, web, test, understanding]
# technical_skills           [ui, react, linux, python, java, sql]

# %% [markdown]
# # Conclusion

# %% [markdown]
# We reached acceptable accuracy with the basic model Naive Bayes.
#
# This solution can be improved by:
# * adding a larger dataset and thus a larger training data for naive bayes algorithm
# * Extracting more accurate adjectives: library TextBlob that we used for this exercice has some inaccuracies when extracting adjectives. For example, it faulty considered the terms "app", "web" "test" as adjectives.
# * Experimenting with other models for better model accuracy score
# * Using bi-grams tokens and not only uni-grams ones.
# * Using technologies such as pyspark to make the data manipulation pipeline more scalable
# * Adding an exhaustive list of technologies
